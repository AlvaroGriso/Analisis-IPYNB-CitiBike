# %%
#Librerías
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Lectura del CSV
df = pd.read_csv("citibike_final_2018.csv", sep="\t")

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0           970  2018-01-01 13:50:57.4340
# 1           1           723  2018-01-01 15:33:30.1820
# 2           2           496  2018-01-01 15:39:18.3370
# 3           3           306  2018-01-01 15:40:13.3720
# 4           4           306  2018-01-01 18:14:51.5680
#
#                    stoptime  start station id start station name  \
# 0  2018-01-01 14:07:08.1860              72.0   W 52 St & 11 Ave
# 1  2018-01-01 15:45:33.3410              72.0   W 52 St & 11 Ave
# 2  2018-01-01 15:47:35.1720              72.0   W 52 St & 11 Ave
# 3  2018-01-01 15:45:20.1910              72.0   W 52 St & 11 Ave
# 4  2018-01-01 18:19:57.6420              72.0   W 52 St & 11 Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.767272               -73.993929           505.0
# 1               40.767272               -73.993929          3255.0
# ...

# %%
#Convertir variable de  milisegundos a minutos
df['tripduration'] = (df['tripduration']/1000) / 60
df2 = df

# %%
df2['tripduration'] = df2['tripduration']*1000
df2.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0     16.166667  2018-01-01 13:50:57.4340
# 1           1     12.050000  2018-01-01 15:33:30.1820
# 2           2      8.266667  2018-01-01 15:39:18.3370
# 3           3      5.100000  2018-01-01 15:40:13.3720
# 4           4      5.100000  2018-01-01 18:14:51.5680
#
#                    stoptime  start station id start station name  \
# 0  2018-01-01 14:07:08.1860              72.0   W 52 St & 11 Ave
# 1  2018-01-01 15:45:33.3410              72.0   W 52 St & 11 Ave
# 2  2018-01-01 15:47:35.1720              72.0   W 52 St & 11 Ave
# 3  2018-01-01 15:45:20.1910              72.0   W 52 St & 11 Ave
# 4  2018-01-01 18:19:57.6420              72.0   W 52 St & 11 Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.767272               -73.993929           505.0
# 1               40.767272               -73.993929          3255.0
# ...

# %%
df2 = df2.drop('Unnamed: 0',axis=1)
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0     16.166667  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1     12.050000  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2      8.266667  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3      5.100000  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4      5.100000  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
#Revisar filas duplicadas
df2.duplicated().sum()
# Out:
# 0

# %%
df2.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.754834e+07      1.754584e+07            1.754834e+07
# mean   1.647905e+01      1.589282e+03            4.073737e+01
# std    3.149306e+02      1.439432e+03            3.225813e-02
# min    1.016667e+00      7.200000e+01            4.064654e+01
# 25%    5.966667e+00      3.800000e+02            4.071755e+01
# 50%    1.008333e+01      5.050000e+02            4.073818e+01
# 75%    1.766667e+01      3.249000e+03            4.075763e+01
# max    3.251675e+05      3.721000e+03            4.550636e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.754834e+07    1.754584e+07          1.754834e+07
# mean             -7.398260e+01    1.580830e+03          4.073704e+01
# std               1.912753e-02    1.438502e+03          3.206583e-02
# min              -7.402535e+01    7.200000e+01          4.064654e+01
# ...

# %%
df2.shape
# Out:
# (17548339, 15)

# %%
#Eliminar filas con datos nulos
df2.dropna()
# Out:
#           tripduration                 starttime                  stoptime  \
# 0            16.166667  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1            12.050000  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2             8.266667  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3             5.100000  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4             5.100000  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# ...                ...                       ...                       ...
# 17548334     12.233333  2018-12-31 23:55:06.9910  2019-01-01 00:07:21.2300
# 17548335     42.516667  2018-12-31 23:55:44.3070  2019-01-01 00:38:15.7820
# 17548336     39.600000  2018-12-31 23:56:52.8500  2019-01-01 00:36:29.2860
# 17548337     45.966667  2018-12-31 23:58:29.2120  2019-01-01 00:44:27.5170
# 17548338     40.983333  2018-12-31 23:59:51.0850  2019-01-01 00:40:50.8800
#
#           start station id            start station name  \
# ...

# %%
df3 = df2.sample(frac=.5)

# %%
df3.shape
# Out:
# (8774170, 15)

# %%
df2.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot: title={'center': 'tripduration'}>,
#         <AxesSubplot: title={'center': 'start station id'}>,
#         <AxesSubplot: title={'center': 'start station latitude'}>],
#        [<AxesSubplot: title={'center': 'start station longitude'}>,
#         <AxesSubplot: title={'center': 'end station id'}>,
#         <AxesSubplot: title={'center': 'end station latitude'}>],
#        [<AxesSubplot: title={'center': 'end station longitude'}>,
#         <AxesSubplot: title={'center': 'bikeid'}>,
#         <AxesSubplot: title={'center': 'birth year'}>],
#        [<AxesSubplot: title={'center': 'gender'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
df3.to_csv('analisis_2018.csv',index=False, header=True, sep=';')

# %%
df2_station = df2['start station name'].value_counts()
df2_station
# Out:
# Pershing Square North    150257
# E 17 St & Broadway       108883
# W 21 St & 6 Ave          107165
# Broadway & E 22 St       105605
# West St & Chambers St     94466
#                           ...
# Apache                        3
# 8D QC Station 01              3
# Handlebar @ Gowanus           2
# E 3 St & 1 Ave                1
# NYCBS Depot - PIT             1
# Name: start station name, Length: 821, dtype: int64
