# %%
#Librerías
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Lectura del CSV
df = pd.read_csv("citibike_final_2013.csv", sep="\t",low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration            starttime             stoptime  \
# 0           0           504  2013-11-01 00:00:17  2013-11-01 00:08:41
# 1           1           747  2013-11-01 00:00:20  2013-11-01 00:12:47
# 2           2          1005  2013-11-01 00:00:30  2013-11-01 00:17:15
# 3           3           622  2013-11-01 00:01:29  2013-11-01 00:11:51
# 4           4          1454  2013-11-01 00:01:37  2013-11-01 00:25:51
#
#    start station id       start station name  start station latitude  \
# 0               326          E 11 St & 1 Ave               40.729538
# 1               375  Mercer St & Bleecker St               40.726795
# 2               264     Maiden Ln & Pearl St               40.707065
# 3               472       E 32 St & Park Ave               40.745712
# 4               293    Lafayette St & E 8 St               40.730287
#
#    start station longitude  end station id          end station name  \
# 0               -73.984267           349.0   Rivington St & Ridge St
# 1               -73.996951           504.0           1 Ave & E 15 St
# 2               -74.007319           265.0  Stanton St & Chrystie St
# 3               -73.981948           174.0           E 25 St & 1 Ave
# 4               -73.990765           490.0           8 Ave & W 33 St
#
#    end station latitude  end station longitude  bikeid    usertype birth year  \
# 0             40.718502             -73.983299   16393  Subscriber       1983
# 1             40.732219             -73.981656   18244  Subscriber       1971
# 2             40.722293             -73.991475   14636    Customer         \N
# 3             40.738177             -73.977387   16685  Subscriber       1980
# 4             40.751551             -73.993934   18055  Subscriber       1975
#
#    gender
# 0       2
# 1       1
# 2       0
# 3       1
# 4       2

# %%
#Convertir variable de  milisegundos a minutos
df['tripduration'] = (df['tripduration']/1000) / 60
df2 = df

# %%
df2['tripduration'] = df2['tripduration']*1000
df2.head()
# Out:
#    Unnamed: 0  tripduration            starttime             stoptime  \
# 0           0      8.400000  2013-11-01 00:00:17  2013-11-01 00:08:41
# 1           1     12.450000  2013-11-01 00:00:20  2013-11-01 00:12:47
# 2           2     16.750000  2013-11-01 00:00:30  2013-11-01 00:17:15
# 3           3     10.366667  2013-11-01 00:01:29  2013-11-01 00:11:51
# 4           4     24.233333  2013-11-01 00:01:37  2013-11-01 00:25:51
#
#    start station id       start station name  start station latitude  \
# 0               326          E 11 St & 1 Ave               40.729538
# 1               375  Mercer St & Bleecker St               40.726795
# 2               264     Maiden Ln & Pearl St               40.707065
# 3               472       E 32 St & Park Ave               40.745712
# 4               293    Lafayette St & E 8 St               40.730287
#
#    start station longitude  end station id          end station name  \
# 0               -73.984267           349.0   Rivington St & Ridge St
# 1               -73.996951           504.0           1 Ave & E 15 St
# 2               -74.007319           265.0  Stanton St & Chrystie St
# 3               -73.981948           174.0           E 25 St & 1 Ave
# 4               -73.990765           490.0           8 Ave & W 33 St
#
#    end station latitude  end station longitude  bikeid    usertype birth year  \
# 0             40.718502             -73.983299   16393  Subscriber       1983
# 1             40.732219             -73.981656   18244  Subscriber       1971
# 2             40.722293             -73.991475   14636    Customer         \N
# 3             40.738177             -73.977387   16685  Subscriber       1980
# 4             40.751551             -73.993934   18055  Subscriber       1975
#
#    gender
# 0       2
# 1       1
# 2       0
# 3       1
# 4       2

# %%
df2 = df2.drop('Unnamed: 0',axis=1)
df2.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0      8.400000  2013-11-01 00:00:17  2013-11-01 00:08:41               326
# 1     12.450000  2013-11-01 00:00:20  2013-11-01 00:12:47               375
# 2     16.750000  2013-11-01 00:00:30  2013-11-01 00:17:15               264
# 3     10.366667  2013-11-01 00:01:29  2013-11-01 00:11:51               472
# 4     24.233333  2013-11-01 00:01:37  2013-11-01 00:25:51               293
#
#         start station name  start station latitude  start station longitude  \
# 0          E 11 St & 1 Ave               40.729538               -73.984267
# 1  Mercer St & Bleecker St               40.726795               -73.996951
# 2     Maiden Ln & Pearl St               40.707065               -74.007319
# 3       E 32 St & Park Ave               40.745712               -73.981948
# 4    Lafayette St & E 8 St               40.730287               -73.990765
#
#    end station id          end station name  end station latitude  \
# 0           349.0   Rivington St & Ridge St             40.718502
# 1           504.0           1 Ave & E 15 St             40.732219
# 2           265.0  Stanton St & Chrystie St             40.722293
# 3           174.0           E 25 St & 1 Ave             40.738177
# 4           490.0           8 Ave & W 33 St             40.751551
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -73.983299   16393  Subscriber       1983       2
# 1             -73.981656   18244  Subscriber       1971       1
# 2             -73.991475   14636    Customer         \N       0
# 3             -73.977387   16685  Subscriber       1980       1
# 4             -73.993934   18055  Subscriber       1975       2

# %%
#Revisar filas duplicadas
df2.duplicated().sum()

# %%
df2.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  5.614888e+06      5.614888e+06            5.614888e+06
# mean   1.562553e+01      4.394108e+02            4.073414e+01
# std    7.735399e+01      3.425676e+02            2.008897e-02
# min    1.000000e+00      7.200000e+01            4.064661e+01
# 25%    6.883333e+00      3.050000e+02            4.072020e+01
# 50%    1.110000e+01      4.020000e+02            4.073588e+01
# 75%    1.840000e+01      4.850000e+02            4.075020e+01
# max    1.041792e+05      3.020000e+03            4.077152e+01
#
#        start station longitude  end station id  end station latitude  \
# count             5.614888e+06    5.596829e+06          5.596829e+06
# mean             -7.399107e+01    4.399593e+02          4.073383e+01
# std               1.248625e-02    3.477844e+02          2.011335e-02
# min              -7.401713e+01    7.200000e+01          4.064661e+01
# 25%              -7.400026e+01    3.040000e+02          4.071939e+01
# 50%              -7.399076e+01    4.020000e+02          4.073535e+01
# 75%              -7.398195e+01    4.830000e+02          4.074972e+01
# max              -7.395005e+01    3.020000e+03          4.077152e+01
#
#        end station longitude        bikeid        gender
# count           5.596829e+06  5.614888e+06  5.614888e+06
# mean           -7.399116e+01  1.764732e+04  1.035652e+00
# std             1.258008e-02  1.726228e+03  5.981432e-01
# min            -7.401713e+01  1.452900e+04  0.000000e+00
# 25%            -7.400150e+01  1.615600e+04  1.000000e+00
# 50%            -7.399093e+01  1.765200e+04  1.000000e+00
# 75%            -7.398195e+01  1.912100e+04  1.000000e+00
# max            -7.395005e+01  2.133300e+04  2.000000e+00

# %%
df2.shape
# Out:
# (5614888, 15)

# %%
#Eliminar filas con datos nulos
df2.dropna()
# Out:
#          tripduration            starttime             stoptime  \
# 0            8.400000  2013-11-01 00:00:17  2013-11-01 00:08:41
# 1           12.450000  2013-11-01 00:00:20  2013-11-01 00:12:47
# 2           16.750000  2013-11-01 00:00:30  2013-11-01 00:17:15
# 3           10.366667  2013-11-01 00:01:29  2013-11-01 00:11:51
# 4           24.233333  2013-11-01 00:01:37  2013-11-01 00:25:51
# ...               ...                  ...                  ...
# 5614872      7.266667  2013-06-30 23:58:09  2013-07-01 00:05:25
# 5614874      3.083333  2013-06-30 23:57:52  2013-07-01 00:00:57
# 5614875      9.916667  2013-06-30 23:58:39  2013-07-01 00:08:34
# 5614883     15.416667  2013-06-30 23:59:27  2013-07-01 00:14:52
# 5614885      2.683333  2013-06-30 23:59:33  2013-07-01 00:02:14
#
#          start station id           start station name  \
# 0                     326              E 11 St & 1 Ave
# 1                     375      Mercer St & Bleecker St
# 2                     264         Maiden Ln & Pearl St
# 3                     472           E 32 St & Park Ave
# 4                     293        Lafayette St & E 8 St
# ...                   ...                          ...
# 5614872               161        LaGuardia Pl & W 3 St
# 5614874               323  Lawrence St & Willoughby St
# 5614875               360         William St & Pine St
# 5614883               509              9 Ave & W 22 St
# 5614885               443         Bedford Ave & S 9 St
#
#          start station latitude  start station longitude  end station id  \
# 0                     40.729538               -73.984267           349.0
# 1                     40.726795               -73.996951           504.0
# 2                     40.707065               -74.007319           265.0
# 3                     40.745712               -73.981948           174.0
# 4                     40.730287               -73.990765           490.0
# ...                         ...                      ...             ...
# 5614872               40.729170               -73.998102           403.0
# 5614874               40.692362               -73.986317           293.0
# 5614875               40.707179               -74.008873           329.0
# 5614883               40.745497               -74.001971           462.0
# 5614885               40.708531               -73.964090           282.0
#
#                       end station name  end station latitude  \
# 0              Rivington St & Ridge St             40.718502
# 1                      1 Ave & E 15 St             40.732219
# 2             Stanton St & Chrystie St             40.722293
# 3                      E 25 St & 1 Ave             40.738177
# 4                      8 Ave & W 33 St             40.751551
# ...                                ...                   ...
# 5614872                 E 2 St & 2 Ave             40.725029
# 5614874          Lafayette St & E 8 St             40.730207
# 5614875  Greenwich St & North Moore St             40.720152
# 5614883               W 22 St & 10 Ave             40.746920
# 5614885             Kent Ave & S 11 St             40.707645
#
#          end station longitude  bikeid    usertype birth year  gender
# 0                   -73.983299   16393  Subscriber       1983       2
# 1                   -73.981656   18244  Subscriber       1971       1
# 2                   -73.991475   14636    Customer         \N       0
# 3                   -73.977387   16685  Subscriber       1980       1
# 4                   -73.993934   18055  Subscriber       1975       2
# ...                        ...     ...         ...        ...     ...
# 5614872             -73.990697   19454  Subscriber     1982.0       1
# 5614874             -73.991026   16746  Subscriber     1982.0       1
# 5614875             -74.010365   19290  Subscriber     1985.0       1
# 5614883             -74.004519   15250  Subscriber     1964.0       1
# 5614885             -73.968415   18910  Subscriber     1972.0       2
#
# [5364026 rows x 15 columns]

# %%
df2.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot: title={'center': 'tripduration'}>,
#         <AxesSubplot: title={'center': 'start station id'}>,
#         <AxesSubplot: title={'center': 'start station latitude'}>],
#        [<AxesSubplot: title={'center': 'start station longitude'}>,
#         <AxesSubplot: title={'center': 'end station id'}>,
#         <AxesSubplot: title={'center': 'end station latitude'}>],
#        [<AxesSubplot: title={'center': 'end station longitude'}>,
#         <AxesSubplot: title={'center': 'bikeid'}>,
#         <AxesSubplot: title={'center': 'gender'}>]], dtype=object)

# %%
df2.to_csv('analisis_2013.csv',index=False, header=True, sep=';')

# %%
df2_station = df2['start station name'].value_counts()
df2_station
# Out:
# E 17 St & Broadway                                55371
# W 20 St & 11 Ave                                  51783
# Lafayette St & E 8 St                             51166
# Pershing Square N                                 50340
# 8 Ave & W 31 St                                   48405
#                                                   ...
# Bedford Ave & S 9 St                                264
# 3969.TEMP (Bike The Branches - Central Branch)      216
# NYCBS Test                                          189
# Sands St & Navy St                                  153
# MLSWKiosk                                             2
# Name: start station name, Length: 367, dtype: int64
