# %%
#Librerías
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Lectura del CSV
df = pd.read_csv("citibike_final_2020.csv", sep="\t")

# %%
df.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0           789  2020-01-01 00:00:55.3900
# 1           1          1541  2020-01-01 00:01:08.1020
# 2           2          1464  2020-01-01 00:01:42.1400
# 3           3           592  2020-01-01 00:01:45.5610
# 4           4           702  2020-01-01 00:01:45.7880
#
#                    stoptime  start station id  \
# 0  2020-01-01 00:14:05.1470               504
# 1  2020-01-01 00:26:49.1780              3423
# 2  2020-01-01 00:26:07.0110              3687
# 3  2020-01-01 00:11:38.1550               346
# 4  2020-01-01 00:13:28.2400               372
#
#                 start station name  start station latitude  \
# 0                  1 Ave & E 16 St               40.732219
# 1  West Drive & Prospect Park West               40.661063
# 2                  E 33 St & 1 Ave               40.743227
# 3              Bank St & Hudson St               40.736529
# ...

# %%
#Convertir variable de  milisegundos a minutos
df['tripduration'] = (df['tripduration']/1000) / 60
df2 = df

# %%
df2['tripduration'] = df2['tripduration']*1000
df2.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0     13.150000  2020-01-01 00:00:55.3900
# 1           1     25.683333  2020-01-01 00:01:08.1020
# 2           2     24.400000  2020-01-01 00:01:42.1400
# 3           3      9.866667  2020-01-01 00:01:45.5610
# 4           4     11.700000  2020-01-01 00:01:45.7880
#
#                    stoptime  start station id  \
# 0  2020-01-01 00:14:05.1470               504
# 1  2020-01-01 00:26:49.1780              3423
# 2  2020-01-01 00:26:07.0110              3687
# 3  2020-01-01 00:11:38.1550               346
# 4  2020-01-01 00:13:28.2400               372
#
#                 start station name  start station latitude  \
# 0                  1 Ave & E 16 St               40.732219
# 1  West Drive & Prospect Park West               40.661063
# 2                  E 33 St & 1 Ave               40.743227
# 3              Bank St & Hudson St               40.736529
# ...

# %%
df2 = df2.drop('Unnamed: 0',axis=1)
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0     13.150000  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1     25.683333  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2     24.400000  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3      9.866667  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4     11.700000  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
df2.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.950686e+07      1.950686e+07            1.950686e+07
# mean   2.184705e+01      2.026080e+03            4.074041e+01
# std    2.372116e+02      1.542732e+03            3.490049e-02
# min    1.016667e+00      7.200000e+01            4.065540e+01
# 25%    7.066667e+00      4.230000e+02            4.071723e+01
# 50%    1.300000e+01      3.077000e+03            4.073945e+01
# 75%    2.340000e+01      3.461000e+03            4.076351e+01
# max    6.310312e+04      4.332000e+03            4.085225e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.950686e+07    1.950686e+07          1.950686e+07
# mean             -7.397708e+01    2.019833e+03          4.074004e+01
# std               2.298853e-02    1.543578e+03          3.480000e-02
# min              -7.402535e+01    7.200000e+01          4.065540e+01
# ...

# %%
df2.shape
# Out:
# (19506857, 15)

# %%
#Revisar filas duplicadas
df2.duplicated().sum()
# Out:
# 0

# %%
df3 = df2.sample(frac=.5)

# %%
df2.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot: title={'center': 'tripduration'}>,
#         <AxesSubplot: title={'center': 'start station id'}>,
#         <AxesSubplot: title={'center': 'start station latitude'}>],
#        [<AxesSubplot: title={'center': 'start station longitude'}>,
#         <AxesSubplot: title={'center': 'end station id'}>,
#         <AxesSubplot: title={'center': 'end station latitude'}>],
#        [<AxesSubplot: title={'center': 'end station longitude'}>,
#         <AxesSubplot: title={'center': 'bikeid'}>,
#         <AxesSubplot: title={'center': 'birth year'}>],
#        [<AxesSubplot: title={'center': 'gender'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
df3.to_csv('analisis_2020.csv',index=False, header=True, sep=';')

# %%
df2_station = df2['start station name'].value_counts()
df2_station
# Out:
# 1 Ave & E 68 St                100753
# West St & Chambers St           99364
# W 21 St & 6 Ave                 99191
# 12 Ave & W 40 St                97415
# Broadway & W 60 St              91856
#                                 ...
# 35 St & 23 Ave                      6
# MTL-AOS-5.1                         3
# W 167 St & St. Nicholas Ave         3
# 24 St & 38 Ave                      2
# Morris Ave & E 163 St               1
# Name: start station name, Length: 1225, dtype: int64
